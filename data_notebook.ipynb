# %%
import plotly.express as px
import pandas as pd
import dash_leaflet as dl
import geopandas
import dash_leaflet.express as dlx
from xgboost import XGBRegressor
import pickle
import json

# %%
df_wmoid = pd.read_excel('./Data/daftar_wmoid.xlsx')
df_wmoid = df_wmoid.rename(columns={'WMOID': 'lokasi'}) # WMOID dataframe preproceses
df_wmoid = df_wmoid[['lokasi', 'Nama UPT']]
df_wmoid
# Out:
#     lokasi                                       Nama UPT
# 0    96001               Stasiun Meteorologi Maimun Saleh
# 1    96009               Stasiun Meteorologi Malikussaleh
# 2    96011       Stasiun Meteorologi Sultan Iskandar Muda
# 3    96013                   Stasiun Geofisika Aceh Besar
# 4    96015  Stasiun Meteorologi Cut Nyak Dhien Nagan Raya
# ..     ...                                            ...
# 180  97876                Stasiun Meteorologi Tanah Merah
# 181  97900         Stasiun Meteorologi Mathilda Batlayeri
# 182  97978                    Stasiun Klimatologi Merauke
# 183  97980                      Stasiun Meteorologi Mopah
# 184  99992                     Balai Besar MKG Wilayah II
#
# [185 rows x 2 columns]

# %%
ina_nwp_input = pd.read_csv('./Data/MONAS-input_nwp_compile.csv') # Feature to predict from INA-NWP
ina_nwp_input
# Out:
#       lokasi                 Date  suhu2m(degC)  dew2m(degC)  rh2m(%)  \
# 0      96001  2023-10-17 15:00:00       27.4007      23.6856  80.3053
# 1      96001  2023-10-17 18:00:00       27.4089      23.0971  77.4673
# 2      96001  2023-10-17 21:00:00       27.3820      23.8747  81.3127
# 3      96001  2023-10-18 00:00:00       27.4679      23.7839  80.4639
# 4      96001  2023-10-18 03:00:00       27.9673      23.2775  75.7992
# ...      ...                  ...           ...          ...      ...
# 4147   99992  2023-10-20 00:00:00       26.8513      19.0878  62.5816
# 4148   99992  2023-10-20 03:00:00       32.5296      17.3364  40.4115
# 4149   99992  2023-10-20 06:00:00       33.2196      21.2222  49.5108
# 4150   99992  2023-10-20 09:00:00       31.2358      21.8844  57.6837
# 4151   99992  2023-10-20 12:00:00       27.6764      23.3754  77.5557
#
#       wspeed(m/s)  wdir(deg)  lcloud(%)  mcloud(%)  hcloud(%)  ...  \
# 0         4.25554  191.08600   0.374474   1.000000   0.855219  ...
# 1         3.20000  228.61600   0.262561   1.000000   0.872848  ...
# 2         6.43993  224.35900   0.431500   1.000000   0.849396  ...
# 3         6.91585  220.91600   0.317385   1.000000   0.524404  ...
# 4         6.28717  214.11300   0.252877   0.785813   0.610115  ...
# ...           ...        ...        ...        ...        ...  ...
# 4147      1.52901  146.67200   0.051358   0.210951   0.000000  ...
# 4148      2.83196   76.91420   0.000000   0.227088   0.000000  ...
# 4149      6.39935   10.12190   0.000000   0.495652   0.000000  ...
# 4150      5.41735    1.79568   0.000000   0.589733   0.000000  ...
# 4151      2.58777  330.03500   0.177541   0.148990   0.000000  ...
#
#       ws800(m/s)  wd800(deg)  t500(degC)  rh500(%)  ws500(m/s)  wd500(deg)  \
# 0        8.18965    242.5890    -4.71925   94.9932     4.68350     76.8328
# 1        6.67126    204.7110    -4.99763   95.7026     4.83021    124.4510
# 2        5.34901    203.9090    -5.10086   95.3166     4.00113    107.2340
# 3        4.76448    191.2090    -4.39951   84.1607     3.31394    114.2420
# 4        3.94272    217.0360    -4.74009   86.5560     3.79705    166.5850
# ...          ...         ...         ...       ...         ...         ...
# 4147     9.53871     94.4738    -4.78717   37.3070     3.18159    304.7020
# 4148    10.88190     99.9526    -4.34492   31.4119     2.67764    274.8970
# 4149     6.33450    121.2080    -4.53275   34.5896     2.30676    282.9150
# 4150     7.09150    106.4220    -4.10275   29.5415     2.16724    244.8240
# 4151     8.18429     91.6887    -4.88776   34.0199     1.56409    190.4350
#
#           prec_nwp      LAT        LON  ELEV
# 0     2.923480e-19  5.87655   95.33785   126
# 1     1.034630e-19  5.87655   95.33785   126
# 2     0.000000e+00  5.87655   95.33785   126
# 3     0.000000e+00  5.87655   95.33785   126
# 4     0.000000e+00  5.87655   95.33785   126
# ...            ...      ...        ...   ...
# 4147  0.000000e+00 -6.30253  106.75636    41
# 4148  0.000000e+00 -6.30253  106.75636    41
# 4149  3.250240e-03 -6.30253  106.75636    41
# 4150  1.239780e-05 -6.30253  106.75636    41
# 4151  0.000000e+00 -6.30253  106.75636    41
#
# [4152 rows x 34 columns]

# %%
# Make merged dataframe for mapping
df_map = df_wmoid.merge(ina_nwp_input, on='lokasi')
df_map = df_map[['lokasi', 'Nama UPT', 'LON', 'LAT']].drop_duplicates()
df_map
# Out:
#      lokasi                                       Nama UPT        LON      LAT
# 0     96001               Stasiun Meteorologi Maimun Saleh   95.33785  5.87655
# 24    96009               Stasiun Meteorologi Malikussaleh   96.94749  5.22869
# 48    96011       Stasiun Meteorologi Sultan Iskandar Muda   95.41700  5.52244
# 72    96015  Stasiun Meteorologi Cut Nyak Dhien Nagan Raya   96.24796  4.04928
# 96    96017                       Stasiun Klimatologi Aceh   95.46400  5.40400
# ...     ...                                            ...        ...      ...
# 3936  97876                Stasiun Meteorologi Tanah Merah  140.31000 -6.10000
# 3960  97900         Stasiun Meteorologi Mathilda Batlayeri  131.30000 -7.98000
# 3984  97978                    Stasiun Klimatologi Merauke  140.51700 -8.38700
# 4008  97980                      Stasiun Meteorologi Mopah  140.41568 -8.52019
# 4032  99992                     Balai Besar MKG Wilayah II  106.75636 -6.30253
#
# [169 rows x 4 columns]

# %%
# INA-NWP input preprocess
ina_nwp_input_filtered = ina_nwp_input.drop(columns=['Date', 'LAT', 'LON'])  
ina_nwp_input_filtered = ina_nwp_input_filtered.rename(
    columns={
        'suhu2m(degC)' : 'suhu2m.degC.',
        'dew2m(degC)' : 'dew2m.degC.',
        'rh2m(%)' : 'rh2m...',
        'wspeed(m/s)' : 'wspeed.m.s.',
        'wdir(deg)' : 'wdir.deg.',
        'lcloud(%)' : 'lcloud...',
        'mcloud(%)' : 'mcloud...' ,
        'hcloud(%)' : 'hcloud...',
        'surpre(Pa)' : 'surpre.Pa.' ,
        'clmix(kg/kg)' : 'clmix.kg.kg.' ,
        'wamix(kg/kg)' : 'wamix.kg.kg.' ,
        'outlr(W/m2)' : 'outlr.W.m2.' ,
        'pblh(m)' : 'pblh.m.',
        'lifcl(m)' : 'lifcl.m.' ,
        'cape(j/kg)' : 'cape.j.kg.' ,
        'mdbz' : 'mdbz' ,
        't950(degC)' : 't950.degC.' ,
        'rh950(%)' : 'rh950...',
        'ws950(m/s)' : 'ws950.m.s.' ,
        'wd950(deg)' : 'wd950.deg.' ,
        't800(degC)' : 't800.degC.' ,
        'rh800(%)' : 'rh800...' ,
        'ws800(m/s)' : 'ws800.m.s.',
        'wd800(deg)' : 'wd800.deg.' ,
        't500(degC)' : 't500.degC.' ,
        'rh500(%)' : 'rh500...' ,
        'ws500(m/s)' : 'ws500.m.s.' ,
        'wd500(deg)' : 'wd500.deg.',
})
ina_nwp_input_filtered
# Out:
#       lokasi  suhu2m.degC.  dew2m.degC.  rh2m...  wspeed.m.s.  wdir.deg.  \
# 0      96001       27.4007      23.6856  80.3053      4.25554  191.08600
# 1      96001       27.4089      23.0971  77.4673      3.20000  228.61600
# 2      96001       27.3820      23.8747  81.3127      6.43993  224.35900
# 3      96001       27.4679      23.7839  80.4639      6.91585  220.91600
# 4      96001       27.9673      23.2775  75.7992      6.28717  214.11300
# ...      ...           ...          ...      ...          ...        ...
# 4147   99992       26.8513      19.0878  62.5816      1.52901  146.67200
# 4148   99992       32.5296      17.3364  40.4115      2.83196   76.91420
# 4149   99992       33.2196      21.2222  49.5108      6.39935   10.12190
# 4150   99992       31.2358      21.8844  57.6837      5.41735    1.79568
# 4151   99992       27.6764      23.3754  77.5557      2.58777  330.03500
#
#       lcloud...  mcloud...  hcloud...  surpre.Pa.  ...  t800.degC.  rh800...  \
# 0      0.374474   1.000000   0.855219    100903.0  ...     16.0404   73.3359
# 1      0.262561   1.000000   0.872848    100735.0  ...     15.9013   73.9679
# 2      0.431500   1.000000   0.849396    100655.0  ...     15.6937   73.0260
# 3      0.317385   1.000000   0.524404    100769.0  ...     15.4617   74.9905
# 4      0.252877   0.785813   0.610115    100950.0  ...     14.9336   76.5370
# ...         ...        ...        ...         ...  ...         ...       ...
# 4147   0.051358   0.210951   0.000000    100571.0  ...     15.3491   71.3439
# 4148   0.000000   0.227088   0.000000    100550.0  ...     15.5818   60.1363
# 4149   0.000000   0.495652   0.000000    100316.0  ...     15.9853   67.9167
# 4150   0.000000   0.589733   0.000000    100266.0  ...     15.8179   74.5408
# 4151   0.177541   0.148990   0.000000    100522.0  ...     15.6176   59.4854
#
#       ws800.m.s.  wd800.deg.  t500.degC.  rh500...  ws500.m.s.  wd500.deg.  \
# 0        8.18965    242.5890    -4.71925   94.9932     4.68350     76.8328
# 1        6.67126    204.7110    -4.99763   95.7026     4.83021    124.4510
# 2        5.34901    203.9090    -5.10086   95.3166     4.00113    107.2340
# 3        4.76448    191.2090    -4.39951   84.1607     3.31394    114.2420
# 4        3.94272    217.0360    -4.74009   86.5560     3.79705    166.5850
# ...          ...         ...         ...       ...         ...         ...
# 4147     9.53871     94.4738    -4.78717   37.3070     3.18159    304.7020
# 4148    10.88190     99.9526    -4.34492   31.4119     2.67764    274.8970
# 4149     6.33450    121.2080    -4.53275   34.5896     2.30676    282.9150
# 4150     7.09150    106.4220    -4.10275   29.5415     2.16724    244.8240
# 4151     8.18429     91.6887    -4.88776   34.0199     1.56409    190.4350
#
#           prec_nwp  ELEV
# 0     2.923480e-19   126
# 1     1.034630e-19   126
# 2     0.000000e+00   126
# 3     0.000000e+00   126
# 4     0.000000e+00   126
# ...            ...   ...
# 4147  0.000000e+00    41
# 4148  0.000000e+00    41
# 4149  3.250240e-03    41
# 4150  1.239780e-05    41
# 4151  0.000000e+00    41
#
# [4152 rows x 31 columns]

# %%
# Functions
def predict_xgb(model_path, columns_to_drop, input_df):
    model = XGBRegressor()
    model.load_model(model_path)
    input_data = input_df.drop(columns=columns_to_drop)
    predictions = model.predict(input_data)
    return predictions

def create_data_table(df_wmoid, df_pred, col_name, merge_column='lokasi'):
    df_pred['Date'] = pd.to_datetime(df_pred['Date'])
    df_pred['day'] = df_pred['Date'].dt.day

    # Group by 'day' and calculate the averages
    df_pred_avg = df_pred.groupby(['lokasi', 'day']).agg({
        'prediction': ['max', 'mean', 'min']
    }).astype('float64').round(1).reset_index()

    # Rename columns
    df_pred_avg.columns = ['lokasi', 'day', f'max_{col_name}', f'mean_{col_name}', f'min_{col_name}']

    # Convert 'Date' to a string format without timezone
    df_pred_avg['Date'] = df_pred_avg['day'].apply(lambda x: f'2023-10-{x:02d}')

    # Rearrange columns
    df_pred_avg = df_pred_avg[['lokasi', 'day', 'Date', f'max_{col_name}', f'mean_{col_name}', f'min_{col_name}']]

    # Merge with df_wmoid
    data_table_lokasi = pd.merge(df_wmoid, df_pred_avg, how='inner', on=merge_column)

    return data_table_lokasi

def plot_graph(df_graph, upt_name, nwp_output, graph_type):
    if graph_type in ['Temperature', 'Humidity'] : 
        figure = px.line(
                df_graph, 
                x='Date', 
                y='prediction', 
                title=f'{graph_type} in UPT {upt_name} (UTF)', 
                markers=True, 
                line_shape='spline'
                )
        
        figure.add_scatter(
                x=df_graph['Date'], 
                y=df_graph[nwp_output], 
                mode='lines', 
                name=f'Output {graph_type} 2m INA-NWP',
                line_shape='spline'
                )
        
        figure.update_layout(
            legend=dict(
                orientation="h",
                yanchor="bottom",
                y=1.02,
                xanchor="right",
                x=1,
                )
            )
        
        return figure
    elif graph_type in ['Precipitation']:
        figure = px.bar(
                df_graph, 
                x='Date', 
                y=['prediction', 'prec_nwp'], 
                title=f'{graph_type} in UPT {upt_name} (UTF)', 
                )
        return figure
    
def generate_output_df(variable_name, original_df, filtered_df, prediction_array):
    df_pred = pd.concat([original_df['Date'], filtered_df[['lokasi', variable_name]], pd.Series(prediction_array, index=filtered_df.index)], axis=1)
    df_pred.columns = ['Date', 'lokasi', variable_name, 'prediction']
    df_pred = df_pred.dropna()
    return df_pred

# %%
# Load ML Models
with open('./models/huber_regressor_bad.pkl','rb') as f:
    prec_model = pickle.load(f)

# Predict precipitation
prec_pred = prec_model.predict(ina_nwp_input_filtered[[
    'lokasi', 'suhu2m.degC.', 'dew2m.degC.', 'rh2m...', 'wspeed.m.s.',
    'wdir.deg.', 'lcloud...', 'mcloud...', 'hcloud...', 'surpre.Pa.',
    'clmix.kg.kg.', 'wamix.kg.kg.', 'outlr.W.m2.', 'pblh.m.', 'lifcl.m.',
    'cape.j.kg.', 'mdbz', 't950.degC.', 'rh950...', 'ws950.m.s.',
    'wd950.deg.', 't800.degC.', 'rh800...', 'ws800.m.s.', 'wd800.deg.',
    't500.degC.', 'rh500...', 'ws500.m.s.', 'wd500.deg.', 'ELEV',
    'prec_nwp'
]])
prec_pred
# Out:
# array([ 0.31072926,  0.28231343,  0.24538189, ..., -0.137372  ,
#        -0.03611404,  0.23338712])

# %%
# Predict temperature
temp_model_path = './models/Temp_xgb_tuned_RMSE_1_441.json'
temp_columns_to_drop = ['lcloud...', 'mcloud...', 'hcloud...', 'clmix.kg.kg.', 'wamix.kg.kg.', 'prec_nwp']
temp_pred = predict_xgb(temp_model_path, temp_columns_to_drop, ina_nwp_input_filtered)
temp_pred
# Out:
# c:\Users\nasut\anaconda3\envs\Oppenheimer\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\Users\nasut\anaconda3\envs\Oppenheimer\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\Users\nasut\anaconda3\envs\Oppenheimer\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\Users\nasut\anaconda3\envs\Oppenheimer\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# array([26.325342, 26.138168, 26.610733, ..., 33.51495 , 32.544765,
#        29.047167], dtype=float32)

# %%
# Predict humidity
humid_model_path = './models/xgbregressor_humidity.json'
humid_columns_to_drop = ['prec_nwp', 'mcloud...', 'wamix.kg.kg.', 'clmix.kg.kg.', 'lcloud...', 'hcloud...']
humid_pred = predict_xgb(humid_model_path, humid_columns_to_drop, ina_nwp_input_filtered)
humid_pred
# Out:
# c:\Users\nasut\anaconda3\envs\Oppenheimer\lib\site-packages\xgboost\core.py:160: UserWarning: [19:09:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0cec3277c4d9d0165-1\xgboost\xgboost-ci-windows\src\learner.cc:873: Found JSON model saved before XGBoost 1.6, please save the model using current version again. The support for old JSON model will be discontinued in XGBoost 2.3.
#   warnings.warn(smsg, UserWarning)
# c:\Users\nasut\anaconda3\envs\Oppenheimer\lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# c:\Users\nasut\anaconda3\envs\Oppenheimer\lib\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# c:\Users\nasut\anaconda3\envs\Oppenheimer\lib\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# c:\Users\nasut\anaconda3\envs\Oppenheimer\lib\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# array([83.37135 , 84.75032 , 81.520134, ..., 48.920624, 56.70622 ,
#        66.43083 ], dtype=float32)

# %%
# OUTPUT temperature
df_pred_temp = generate_output_df('suhu2m.degC.', ina_nwp_input, ina_nwp_input_filtered, temp_pred)
df_pred_temp
# Out:
#                      Date  lokasi  suhu2m.degC.  prediction
# 0     2023-10-17 15:00:00   96001       27.4007   26.325342
# 1     2023-10-17 18:00:00   96001       27.4089   26.138168
# 2     2023-10-17 21:00:00   96001       27.3820   26.610733
# 3     2023-10-18 00:00:00   96001       27.4679   26.819075
# 4     2023-10-18 03:00:00   96001       27.9673   27.512775
# ...                   ...     ...           ...         ...
# 4147  2023-10-20 00:00:00   99992       26.8513   26.116001
# 4148  2023-10-20 03:00:00   99992       32.5296   32.549381
# 4149  2023-10-20 06:00:00   99992       33.2196   33.514950
# 4150  2023-10-20 09:00:00   99992       31.2358   32.544765
# 4151  2023-10-20 12:00:00   99992       27.6764   29.047167
#
# [4152 rows x 4 columns]

# %%
# OUTPUT humidity
df_pred_humid = generate_output_df('rh2m...', ina_nwp_input, ina_nwp_input_filtered, humid_pred)
df_pred_humid
# Out:
#                      Date  lokasi  rh2m...  prediction
# 0     2023-10-17 15:00:00   96001  80.3053   83.371353
# 1     2023-10-17 18:00:00   96001  77.4673   84.750320
# 2     2023-10-17 21:00:00   96001  81.3127   81.520134
# 3     2023-10-18 00:00:00   96001  80.4639   81.959892
# 4     2023-10-18 03:00:00   96001  75.7992   70.463509
# ...                   ...     ...      ...         ...
# 4147  2023-10-20 00:00:00   99992  62.5816   80.262512
# 4148  2023-10-20 03:00:00   99992  40.4115   53.427265
# 4149  2023-10-20 06:00:00   99992  49.5108   48.920624
# 4150  2023-10-20 09:00:00   99992  57.6837   56.706219
# 4151  2023-10-20 12:00:00   99992  77.5557   66.430832
#
# [4152 rows x 4 columns]

# %%
# OUTPUT precipitation
df_pred_prec = generate_output_df('prec_nwp', ina_nwp_input, ina_nwp_input_filtered, prec_pred)
df_pred_prec
# Out:
#                      Date  lokasi      prec_nwp  prediction
# 0     2023-10-17 15:00:00   96001  2.923480e-19    0.310729
# 1     2023-10-17 18:00:00   96001  1.034630e-19    0.282313
# 2     2023-10-17 21:00:00   96001  0.000000e+00    0.245382
# 3     2023-10-18 00:00:00   96001  0.000000e+00    0.234680
# 4     2023-10-18 03:00:00   96001  0.000000e+00    0.139990
# ...                   ...     ...           ...         ...
# 4147  2023-10-20 00:00:00   99992  0.000000e+00   -0.176199
# 4148  2023-10-20 03:00:00   99992  0.000000e+00   -0.187036
# 4149  2023-10-20 06:00:00   99992  3.250240e-03   -0.137372
# 4150  2023-10-20 09:00:00   99992  1.239780e-05   -0.036114
# 4151  2023-10-20 12:00:00   99992  0.000000e+00    0.233387
#
# [4152 rows x 4 columns]

# %%
data_table_lokasi_temp = create_data_table(df_wmoid, df_pred_temp, 'temp', merge_column='lokasi')
data_table_lokasi_temp
# Out:
#     lokasi                          Nama UPT  day        Date  max_temp  \
# 0    96001  Stasiun Meteorologi Maimun Saleh   17  2023-10-17      26.6
# 1    96001  Stasiun Meteorologi Maimun Saleh   18  2023-10-18      28.2
# 2    96001  Stasiun Meteorologi Maimun Saleh   19  2023-10-19      27.5
# 3    96001  Stasiun Meteorologi Maimun Saleh   20  2023-10-20      28.0
# 4    96009  Stasiun Meteorologi Malikussaleh   17  2023-10-17      25.5
# ..     ...                               ...  ...         ...       ...
# 671  97980         Stasiun Meteorologi Mopah   20  2023-10-20      31.6
# 672  99992        Balai Besar MKG Wilayah II   17  2023-10-17      28.6
# 673  99992        Balai Besar MKG Wilayah II   18  2023-10-18      33.5
# 674  99992        Balai Besar MKG Wilayah II   19  2023-10-19      33.5
# 675  99992        Balai Besar MKG Wilayah II   20  2023-10-20      33.5
#
#      mean_temp  min_temp
# 0         26.4      26.1
# 1         27.4      26.8
# 2         27.1      26.3
# 3         27.7      26.9
# 4         25.4      25.2
# ..         ...       ...
# 671       29.7      26.3
# 672       26.3      25.0
# 673       29.2      25.0
# 674       28.8      24.4
# 675       30.8      26.1
#
# [676 rows x 7 columns]

# %%
data_table_lokasi_humid = create_data_table(df_wmoid, df_pred_humid, 'humidity', merge_column='lokasi')
data_table_lokasi_humid
# Out:
#     lokasi                          Nama UPT  day        Date  max_humidity  \
# 0    96001  Stasiun Meteorologi Maimun Saleh   17  2023-10-17          84.8
# 1    96001  Stasiun Meteorologi Maimun Saleh   18  2023-10-18          87.3
# 2    96001  Stasiun Meteorologi Maimun Saleh   19  2023-10-19          92.6
# 3    96001  Stasiun Meteorologi Maimun Saleh   20  2023-10-20          85.5
# 4    96009  Stasiun Meteorologi Malikussaleh   17  2023-10-17          98.7
# ..     ...                               ...  ...         ...           ...
# 671  97980         Stasiun Meteorologi Mopah   20  2023-10-20          88.5
# 672  99992        Balai Besar MKG Wilayah II   17  2023-10-17          82.2
# 673  99992        Balai Besar MKG Wilayah II   18  2023-10-18          87.3
# 674  99992        Balai Besar MKG Wilayah II   19  2023-10-19          84.8
# 675  99992        Balai Besar MKG Wilayah II   20  2023-10-20          80.3
#
#      mean_humidity  min_humidity
# 0             83.2          81.5
# 1             79.6          70.5
# 2             87.2          83.9
# 3             79.3          74.5
# 4             95.4          93.2
# ..             ...           ...
# 671           77.2          68.9
# 672           77.8          70.1
# 673           69.9          50.5
# 674           66.9          39.6
# 675           61.1          48.9
#
# [676 rows x 7 columns]

# %%
data_table_lokasi_prec = create_data_table(df_wmoid, df_pred_prec, 'precipitation', merge_column='lokasi')
data_table_lokasi_prec
# Out:
#     lokasi                          Nama UPT  day        Date  \
# 0    96001  Stasiun Meteorologi Maimun Saleh   17  2023-10-17
# 1    96001  Stasiun Meteorologi Maimun Saleh   18  2023-10-18
# 2    96001  Stasiun Meteorologi Maimun Saleh   19  2023-10-19
# 3    96001  Stasiun Meteorologi Maimun Saleh   20  2023-10-20
# 4    96009  Stasiun Meteorologi Malikussaleh   17  2023-10-17
# ..     ...                               ...  ...         ...
# 671  97980         Stasiun Meteorologi Mopah   20  2023-10-20
# 672  99992        Balai Besar MKG Wilayah II   17  2023-10-17
# 673  99992        Balai Besar MKG Wilayah II   18  2023-10-18
# 674  99992        Balai Besar MKG Wilayah II   19  2023-10-19
# 675  99992        Balai Besar MKG Wilayah II   20  2023-10-20
#
#      max_precipitation  mean_precipitation  min_precipitation
# 0                  0.3                 0.3                0.2
# 1                  0.3                 0.2                0.1
# 2                  0.4                 0.3                0.2
# 3                  0.3                 0.2                0.2
# 4                  0.4                 0.3                0.3
# ..                 ...                 ...                ...
# 671                0.1                 0.1               -0.0
# 672                0.2                 0.2                0.1
# 673                0.3                 0.1               -0.1
# 674                0.2                 0.1               -0.3
# 675                0.2                -0.1               -0.2
#
# [676 rows x 7 columns]

# %%
# Merge the dataframes
data_table_lokasi = data_table_lokasi_temp.merge(data_table_lokasi_humid.drop(columns=['Nama UPT', 'day']), on=['lokasi', 'Date'], how='left').merge(data_table_lokasi_prec.drop(columns=['Nama UPT', 'day']), on=['lokasi', 'Date'], how='left')
data_table_lokasi
# Out:
#     lokasi                          Nama UPT  day        Date  max_temp  \
# 0    96001  Stasiun Meteorologi Maimun Saleh   17  2023-10-17      26.6
# 1    96001  Stasiun Meteorologi Maimun Saleh   18  2023-10-18      28.2
# 2    96001  Stasiun Meteorologi Maimun Saleh   19  2023-10-19      27.5
# 3    96001  Stasiun Meteorologi Maimun Saleh   20  2023-10-20      28.0
# 4    96009  Stasiun Meteorologi Malikussaleh   17  2023-10-17      25.5
# ..     ...                               ...  ...         ...       ...
# 671  97980         Stasiun Meteorologi Mopah   20  2023-10-20      31.6
# 672  99992        Balai Besar MKG Wilayah II   17  2023-10-17      28.6
# 673  99992        Balai Besar MKG Wilayah II   18  2023-10-18      33.5
# 674  99992        Balai Besar MKG Wilayah II   19  2023-10-19      33.5
# 675  99992        Balai Besar MKG Wilayah II   20  2023-10-20      33.5
#
#      mean_temp  min_temp  max_humidity  mean_humidity  min_humidity  \
# 0         26.4      26.1          84.8           83.2          81.5
# 1         27.4      26.8          87.3           79.6          70.5
# 2         27.1      26.3          92.6           87.2          83.9
# 3         27.7      26.9          85.5           79.3          74.5
# 4         25.4      25.2          98.7           95.4          93.2
# ..         ...       ...           ...            ...           ...
# 671       29.7      26.3          88.5           77.2          68.9
# 672       26.3      25.0          82.2           77.8          70.1
# 673       29.2      25.0          87.3           69.9          50.5
# 674       28.8      24.4          84.8           66.9          39.6
# 675       30.8      26.1          80.3           61.1          48.9
#
#      max_precipitation  mean_precipitation  min_precipitation
# 0                  0.3                 0.3                0.2
# 1                  0.3                 0.2                0.1
# 2                  0.4                 0.3                0.2
# 3                  0.3                 0.2                0.2
# 4                  0.4                 0.3                0.3
# ..                 ...                 ...                ...
# 671                0.1                 0.1               -0.0
# 672                0.2                 0.2                0.1
# 673                0.3                 0.1               -0.1
# 674                0.2                 0.1               -0.3
# 675                0.2                -0.1               -0.2
#
# [676 rows x 13 columns]

# %%
# Make geopandas geometry for coordinates
geometry = geopandas.points_from_xy(df_map.LON, df_map.LAT)
upt_gpd = geopandas.GeoDataFrame(df_map, geometry=geometry)
upt_gpd
# Out:
#      lokasi                                       Nama UPT        LON  \
# 0     96001               Stasiun Meteorologi Maimun Saleh   95.33785
# 24    96009               Stasiun Meteorologi Malikussaleh   96.94749
# 48    96011       Stasiun Meteorologi Sultan Iskandar Muda   95.41700
# 72    96015  Stasiun Meteorologi Cut Nyak Dhien Nagan Raya   96.24796
# 96    96017                       Stasiun Klimatologi Aceh   95.46400
# ...     ...                                            ...        ...
# 3936  97876                Stasiun Meteorologi Tanah Merah  140.31000
# 3960  97900         Stasiun Meteorologi Mathilda Batlayeri  131.30000
# 3984  97978                    Stasiun Klimatologi Merauke  140.51700
# 4008  97980                      Stasiun Meteorologi Mopah  140.41568
# 4032  99992                     Balai Besar MKG Wilayah II  106.75636
#
#           LAT                    geometry
# 0     5.87655    POINT (95.33785 5.87655)
# 24    5.22869    POINT (96.94749 5.22869)
# 48    5.52244    POINT (95.41700 5.52244)
# 72    4.04928    POINT (96.24796 4.04928)
# 96    5.40400    POINT (95.46400 5.40400)
# ...       ...                         ...
# 3936 -6.10000  POINT (140.31000 -6.10000)
# 3960 -7.98000  POINT (131.30000 -7.98000)
# 3984 -8.38700  POINT (140.51700 -8.38700)
# 4008 -8.52019  POINT (140.41568 -8.52019)
# 4032 -6.30253  POINT (106.75636 -6.30253)
#
# [169 rows x 5 columns]

# %%
upt_gpd_merged = pd.merge(upt_gpd, data_table_lokasi[data_table_lokasi.drop(columns=['Nama UPT']).columns], on='lokasi')
upt_gpd_merged = upt_gpd_merged.reset_index(drop=True)
upt_gpd_merged
# Out:
#     lokasi                          Nama UPT        LON      LAT  \
# 0    96001  Stasiun Meteorologi Maimun Saleh   95.33785  5.87655
# 1    96001  Stasiun Meteorologi Maimun Saleh   95.33785  5.87655
# 2    96001  Stasiun Meteorologi Maimun Saleh   95.33785  5.87655
# 3    96001  Stasiun Meteorologi Maimun Saleh   95.33785  5.87655
# 4    96009  Stasiun Meteorologi Malikussaleh   96.94749  5.22869
# ..     ...                               ...        ...      ...
# 671  97980         Stasiun Meteorologi Mopah  140.41568 -8.52019
# 672  99992        Balai Besar MKG Wilayah II  106.75636 -6.30253
# 673  99992        Balai Besar MKG Wilayah II  106.75636 -6.30253
# 674  99992        Balai Besar MKG Wilayah II  106.75636 -6.30253
# 675  99992        Balai Besar MKG Wilayah II  106.75636 -6.30253
#
#                        geometry  day        Date  max_temp  mean_temp  \
# 0      POINT (95.33785 5.87655)   17  2023-10-17      26.6       26.4
# 1      POINT (95.33785 5.87655)   18  2023-10-18      28.2       27.4
# 2      POINT (95.33785 5.87655)   19  2023-10-19      27.5       27.1
# 3      POINT (95.33785 5.87655)   20  2023-10-20      28.0       27.7
# 4      POINT (96.94749 5.22869)   17  2023-10-17      25.5       25.4
# ..                          ...  ...         ...       ...        ...
# 671  POINT (140.41568 -8.52019)   20  2023-10-20      31.6       29.7
# 672  POINT (106.75636 -6.30253)   17  2023-10-17      28.6       26.3
# 673  POINT (106.75636 -6.30253)   18  2023-10-18      33.5       29.2
# 674  POINT (106.75636 -6.30253)   19  2023-10-19      33.5       28.8
# 675  POINT (106.75636 -6.30253)   20  2023-10-20      33.5       30.8
#
#      min_temp  max_humidity  mean_humidity  min_humidity  max_precipitation  \
# 0        26.1          84.8           83.2          81.5                0.3
# 1        26.8          87.3           79.6          70.5                0.3
# 2        26.3          92.6           87.2          83.9                0.4
# 3        26.9          85.5           79.3          74.5                0.3
# 4        25.2          98.7           95.4          93.2                0.4
# ..        ...           ...            ...           ...                ...
# 671      26.3          88.5           77.2          68.9                0.1
# 672      25.0          82.2           77.8          70.1                0.2
# 673      25.0          87.3           69.9          50.5                0.3
# 674      24.4          84.8           66.9          39.6                0.2
# 675      26.1          80.3           61.1          48.9                0.2
#
#      mean_precipitation  min_precipitation
# 0                   0.3                0.2
# 1                   0.2                0.1
# 2                   0.3                0.2
# 3                   0.2                0.2
# 4                   0.3                0.3
# ..                  ...                ...
# 671                 0.1               -0.0
# 672                 0.2                0.1
# 673                 0.1               -0.1
# 674                 0.1               -0.3
# 675                -0.1               -0.2
#
# [676 rows x 16 columns]

# %%
geojson = json.loads(upt_gpd_merged.to_json())
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'id': '0',
#    'type': 'Feature',
#    'properties': {'lokasi': 96001,
#     'Nama UPT': 'Stasiun Meteorologi Maimun Saleh',
#     'LON': 95.33785,
#     'LAT': 5.87655,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 26.6,
#     'mean_temp': 26.4,
#     'min_temp': 26.1,
#     'max_humidity': 84.8,
#     'mean_humidity': 83.2,
#     'min_humidity': 81.5,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [95.33785, 5.87655]}},
#   {'id': '1',
#    'type': 'Feature',
#    'properties': {'lokasi': 96001,
#     'Nama UPT': 'Stasiun Meteorologi Maimun Saleh',
#     'LON': 95.33785,
#     'LAT': 5.87655,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 28.2,
#     'mean_temp': 27.4,
#     'min_temp': 26.8,
#     'max_humidity': 87.3,
#     'mean_humidity': 79.6,
#     'min_humidity': 70.5,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [95.33785, 5.87655]}},
#   {'id': '2',
#    'type': 'Feature',
#    'properties': {'lokasi': 96001,
#     'Nama UPT': 'Stasiun Meteorologi Maimun Saleh',
#     'LON': 95.33785,
#     'LAT': 5.87655,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 27.5,
#     'mean_temp': 27.1,
#     'min_temp': 26.3,
#     'max_humidity': 92.6,
#     'mean_humidity': 87.2,
#     'min_humidity': 83.9,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [95.33785, 5.87655]}},
#   {'id': '3',
#    'type': 'Feature',
#    'properties': {'lokasi': 96001,
#     'Nama UPT': 'Stasiun Meteorologi Maimun Saleh',
#     'LON': 95.33785,
#     'LAT': 5.87655,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 28.0,
#     'mean_temp': 27.7,
#     'min_temp': 26.9,
#     'max_humidity': 85.5,
#     'mean_humidity': 79.3,
#     'min_humidity': 74.5,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [95.33785, 5.87655]}},
#   {'id': '4',
#    'type': 'Feature',
#    'properties': {'lokasi': 96009,
#     'Nama UPT': 'Stasiun Meteorologi Malikussaleh',
#     'LON': 96.94749,
#     'LAT': 5.22869,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 25.5,
#     'mean_temp': 25.4,
#     'min_temp': 25.2,
#     'max_humidity': 98.7,
#     'mean_humidity': 95.4,
#     'min_humidity': 93.2,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [96.94749, 5.22869]}},
#   {'id': '5',
#    'type': 'Feature',
#    'properties': {'lokasi': 96009,
#     'Nama UPT': 'Stasiun Meteorologi Malikussaleh',
#     'LON': 96.94749,
#     'LAT': 5.22869,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 29.4,
#     'mean_temp': 27.0,
#     'min_temp': 25.3,
#     'max_humidity': 94.5,
#     'mean_humidity': 85.9,
#     'min_humidity': 73.2,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.1,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [96.94749, 5.22869]}},
#   {'id': '6',
#    'type': 'Feature',
#    'properties': {'lokasi': 96009,
#     'Nama UPT': 'Stasiun Meteorologi Malikussaleh',
#     'LON': 96.94749,
#     'LAT': 5.22869,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 30.1,
#     'mean_temp': 27.1,
#     'min_temp': 24.6,
#     'max_humidity': 95.9,
#     'mean_humidity': 85.8,
#     'min_humidity': 72.7,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [96.94749, 5.22869]}},
#   {'id': '7',
#    'type': 'Feature',
#    'properties': {'lokasi': 96009,
#     'Nama UPT': 'Stasiun Meteorologi Malikussaleh',
#     'LON': 96.94749,
#     'LAT': 5.22869,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 28.7,
#     'mean_temp': 27.5,
#     'min_temp': 25.5,
#     'max_humidity': 93.3,
#     'mean_humidity': 82.8,
#     'min_humidity': 75.4,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [96.94749, 5.22869]}},
#   {'id': '8',
#    'type': 'Feature',
#    'properties': {'lokasi': 96011,
#     'Nama UPT': 'Stasiun Meteorologi Sultan Iskandar Muda',
#     'LON': 95.417,
#     'LAT': 5.52244,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 25.0,
#     'mean_temp': 25.0,
#     'min_temp': 24.9,
#     'max_humidity': 94.8,
#     'mean_humidity': 92.7,
#     'min_humidity': 89.9,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [95.417, 5.52244]}},
#   {'id': '9',
#    'type': 'Feature',
#    'properties': {'lokasi': 96011,
#     'Nama UPT': 'Stasiun Meteorologi Sultan Iskandar Muda',
#     'LON': 95.417,
#     'LAT': 5.52244,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 31.2,
#     'mean_temp': 27.0,
#     'min_temp': 24.4,
#     'max_humidity': 94.4,
#     'mean_humidity': 85.2,
#     'min_humidity': 71.0,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [95.417, 5.52244]}},
#   {'id': '10',
#    'type': 'Feature',
#    'properties': {'lokasi': 96011,
#     'Nama UPT': 'Stasiun Meteorologi Sultan Iskandar Muda',
#     'LON': 95.417,
#     'LAT': 5.52244,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 29.7,
#     'mean_temp': 26.6,
#     'min_temp': 24.5,
#     'max_humidity': 93.9,
#     'mean_humidity': 86.0,
#     'min_humidity': 71.3,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [95.417, 5.52244]}},
#   {'id': '11',
#    'type': 'Feature',
#    'properties': {'lokasi': 96011,
#     'Nama UPT': 'Stasiun Meteorologi Sultan Iskandar Muda',
#     'LON': 95.417,
#     'LAT': 5.52244,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 29.6,
#     'mean_temp': 27.5,
#     'min_temp': 24.9,
#     'max_humidity': 94.7,
#     'mean_humidity': 81.4,
#     'min_humidity': 72.3,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [95.417, 5.52244]}},
#   {'id': '12',
#    'type': 'Feature',
#    'properties': {'lokasi': 96015,
#     'Nama UPT': 'Stasiun Meteorologi Cut Nyak Dhien Nagan Raya',
#     'LON': 96.24796,
#     'LAT': 4.04928,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 25.6,
#     'mean_temp': 25.3,
#     'min_temp': 25.2,
#     'max_humidity': 98.4,
#     'mean_humidity': 96.6,
#     'min_humidity': 94.5,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [96.24796, 4.04928]}},
#   {'id': '13',
#    'type': 'Feature',
#    'properties': {'lokasi': 96015,
#     'Nama UPT': 'Stasiun Meteorologi Cut Nyak Dhien Nagan Raya',
#     'LON': 96.24796,
#     'LAT': 4.04928,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 28.1,
#     'mean_temp': 26.5,
#     'min_temp': 25.0,
#     'max_humidity': 99.4,
#     'mean_humidity': 90.9,
#     'min_humidity': 82.7,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [96.24796, 4.04928]}},
#   {'id': '14',
#    'type': 'Feature',
#    'properties': {'lokasi': 96015,
#     'Nama UPT': 'Stasiun Meteorologi Cut Nyak Dhien Nagan Raya',
#     'LON': 96.24796,
#     'LAT': 4.04928,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 28.2,
#     'mean_temp': 26.5,
#     'min_temp': 25.4,
#     'max_humidity': 98.8,
#     'mean_humidity': 94.0,
#     'min_humidity': 82.0,
#     'max_precipitation': 0.6,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [96.24796, 4.04928]}},
#   {'id': '15',
#    'type': 'Feature',
#    'properties': {'lokasi': 96015,
#     'Nama UPT': 'Stasiun Meteorologi Cut Nyak Dhien Nagan Raya',
#     'LON': 96.24796,
#     'LAT': 4.04928,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 26.8,
#     'mean_temp': 26.2,
#     'min_temp': 25.6,
#     'max_humidity': 98.2,
#     'mean_humidity': 92.6,
#     'min_humidity': 89.4,
#     'max_precipitation': 0.6,
#     'mean_precipitation': 0.5,
#     'min_precipitation': 0.4},
#    'geometry': {'type': 'Point', 'coordinates': [96.24796, 4.04928]}},
#   {'id': '16',
#    'type': 'Feature',
#    'properties': {'lokasi': 96017,
#     'Nama UPT': 'Stasiun Klimatologi Aceh',
#     'LON': 95.464,
#     'LAT': 5.404,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 25.0,
#     'mean_temp': 24.9,
#     'min_temp': 24.9,
#     'max_humidity': 99.5,
#     'mean_humidity': 95.9,
#     'min_humidity': 93.2,
#     'max_precipitation': 0.3,
#     'mean_precipitation': -0.1,
#     'min_precipitation': -0.3},
#    'geometry': {'type': 'Point', 'coordinates': [95.464, 5.404]}},
#   {'id': '17',
#    'type': 'Feature',
#    'properties': {'lokasi': 96017,
#     'Nama UPT': 'Stasiun Klimatologi Aceh',
#     'LON': 95.464,
#     'LAT': 5.404,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 30.9,
#     'mean_temp': 27.2,
#     'min_temp': 24.7,
#     'max_humidity': 98.4,
#     'mean_humidity': 87.1,
#     'min_humidity': 68.1,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.1,
#     'min_precipitation': -0.1},
#    'geometry': {'type': 'Point', 'coordinates': [95.464, 5.404]}},
#   {'id': '18',
#    'type': 'Feature',
#    'properties': {'lokasi': 96017,
#     'Nama UPT': 'Stasiun Klimatologi Aceh',
#     'LON': 95.464,
#     'LAT': 5.404,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 31.1,
#     'mean_temp': 27.1,
#     'min_temp': 24.8,
#     'max_humidity': 97.2,
#     'mean_humidity': 87.1,
#     'min_humidity': 70.4,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [95.464, 5.404]}},
#   {'id': '19',
#    'type': 'Feature',
#    'properties': {'lokasi': 96017,
#     'Nama UPT': 'Stasiun Klimatologi Aceh',
#     'LON': 95.464,
#     'LAT': 5.404,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 30.1,
#     'mean_temp': 28.0,
#     'min_temp': 25.2,
#     'max_humidity': 95.9,
#     'mean_humidity': 83.8,
#     'min_humidity': 73.3,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [95.464, 5.404]}},
#   {'id': '20',
#    'type': 'Feature',
#    'properties': {'lokasi': 96031,
#     'Nama UPT': 'Stasiun Klimatologi Sumatera Utara',
#     'LON': 98.71485,
#     'LAT': 3.62114,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 25.5,
#     'mean_temp': 25.0,
#     'min_temp': 24.6,
#     'max_humidity': 96.2,
#     'mean_humidity': 94.7,
#     'min_humidity': 93.2,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [98.71485, 3.62114]}},
#   {'id': '21',
#    'type': 'Feature',
#    'properties': {'lokasi': 96031,
#     'Nama UPT': 'Stasiun Klimatologi Sumatera Utara',
#     'LON': 98.71485,
#     'LAT': 3.62114,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 30.2,
#     'mean_temp': 27.0,
#     'min_temp': 24.9,
#     'max_humidity': 94.3,
#     'mean_humidity': 86.4,
#     'min_humidity': 73.1,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.1},
#    'geometry': {'type': 'Point', 'coordinates': [98.71485, 3.62114]}},
#   {'id': '22',
#    'type': 'Feature',
#    'properties': {'lokasi': 96031,
#     'Nama UPT': 'Stasiun Klimatologi Sumatera Utara',
#     'LON': 98.71485,
#     'LAT': 3.62114,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 30.3,
#     'mean_temp': 27.4,
#     'min_temp': 24.9,
#     'max_humidity': 94.7,
#     'mean_humidity': 84.2,
#     'min_humidity': 71.6,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [98.71485, 3.62114]}},
#   {'id': '23',
#    'type': 'Feature',
#    'properties': {'lokasi': 96031,
#     'Nama UPT': 'Stasiun Klimatologi Sumatera Utara',
#     'LON': 98.71485,
#     'LAT': 3.62114,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 28.6,
#     'mean_temp': 27.2,
#     'min_temp': 24.9,
#     'max_humidity': 94.9,
#     'mean_humidity': 83.7,
#     'min_humidity': 75.6,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [98.71485, 3.62114]}},
#   {'id': '24',
#    'type': 'Feature',
#    'properties': {'lokasi': 96033,
#     'Nama UPT': 'Stasiun Meteorologi Maritim Belawan',
#     'LON': 98.71492,
#     'LAT': 3.78824,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 25.6,
#     'mean_temp': 25.3,
#     'min_temp': 24.7,
#     'max_humidity': 90.0,
#     'mean_humidity': 88.0,
#     'min_humidity': 86.4,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.4},
#    'geometry': {'type': 'Point', 'coordinates': [98.71492, 3.78824]}},
#   {'id': '25',
#    'type': 'Feature',
#    'properties': {'lokasi': 96033,
#     'Nama UPT': 'Stasiun Meteorologi Maritim Belawan',
#     'LON': 98.71492,
#     'LAT': 3.78824,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 29.7,
#     'mean_temp': 27.1,
#     'min_temp': 24.9,
#     'max_humidity': 89.5,
#     'mean_humidity': 83.1,
#     'min_humidity': 73.7,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [98.71492, 3.78824]}},
#   {'id': '26',
#    'type': 'Feature',
#    'properties': {'lokasi': 96033,
#     'Nama UPT': 'Stasiun Meteorologi Maritim Belawan',
#     'LON': 98.71492,
#     'LAT': 3.78824,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 30.0,
#     'mean_temp': 27.5,
#     'min_temp': 25.0,
#     'max_humidity': 90.6,
#     'mean_humidity': 82.5,
#     'min_humidity': 72.5,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [98.71492, 3.78824]}},
#   {'id': '27',
#    'type': 'Feature',
#    'properties': {'lokasi': 96033,
#     'Nama UPT': 'Stasiun Meteorologi Maritim Belawan',
#     'LON': 98.71492,
#     'LAT': 3.78824,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 28.7,
#     'mean_temp': 27.5,
#     'min_temp': 25.4,
#     'max_humidity': 87.8,
#     'mean_humidity': 80.1,
#     'min_humidity': 75.3,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [98.71492, 3.78824]}},
#   {'id': '28',
#    'type': 'Feature',
#    'properties': {'lokasi': 96035,
#     'Nama UPT': 'Stasiun Meteorologi Kualanamu',
#     'LON': 98.88488,
#     'LAT': 3.64573,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 25.5,
#     'mean_temp': 25.3,
#     'min_temp': 25.2,
#     'max_humidity': 94.1,
#     'mean_humidity': 93.7,
#     'min_humidity': 93.0,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.4},
#    'geometry': {'type': 'Point', 'coordinates': [98.88488, 3.64573]}},
#   {'id': '29',
#    'type': 'Feature',
#    'properties': {'lokasi': 96035,
#     'Nama UPT': 'Stasiun Meteorologi Kualanamu',
#     'LON': 98.88488,
#     'LAT': 3.64573,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 29.8,
#     'mean_temp': 26.9,
#     'min_temp': 24.8,
#     'max_humidity': 95.3,
#     'mean_humidity': 86.4,
#     'min_humidity': 74.8,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [98.88488, 3.64573]}},
#   {'id': '30',
#    'type': 'Feature',
#    'properties': {'lokasi': 96035,
#     'Nama UPT': 'Stasiun Meteorologi Kualanamu',
#     'LON': 98.88488,
#     'LAT': 3.64573,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 29.2,
#     'mean_temp': 26.9,
#     'min_temp': 25.0,
#     'max_humidity': 94.6,
#     'mean_humidity': 85.9,
#     'min_humidity': 75.3,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [98.88488, 3.64573]}},
#   {'id': '31',
#    'type': 'Feature',
#    'properties': {'lokasi': 96035,
#     'Nama UPT': 'Stasiun Meteorologi Kualanamu',
#     'LON': 98.88488,
#     'LAT': 3.64573,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 28.3,
#     'mean_temp': 27.1,
#     'min_temp': 25.1,
#     'max_humidity': 94.9,
#     'mean_humidity': 86.4,
#     'min_humidity': 81.4,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [98.88488, 3.64573]}},
#   {'id': '32',
#    'type': 'Feature',
#    'properties': {'lokasi': 96037,
#     'Nama UPT': 'Stasiun Geofisika Deli Serdang',
#     'LON': 98.56,
#     'LAT': 3.501,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 24.9,
#     'mean_temp': 24.6,
#     'min_temp': 24.2,
#     'max_humidity': 99.5,
#     'mean_humidity': 98.0,
#     'min_humidity': 95.0,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.1,
#     'min_precipitation': -0.2},
#    'geometry': {'type': 'Point', 'coordinates': [98.56, 3.501]}},
#   {'id': '33',
#    'type': 'Feature',
#    'properties': {'lokasi': 96037,
#     'Nama UPT': 'Stasiun Geofisika Deli Serdang',
#     'LON': 98.56,
#     'LAT': 3.501,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 31.6,
#     'mean_temp': 27.0,
#     'min_temp': 24.5,
#     'max_humidity': 97.6,
#     'mean_humidity': 87.1,
#     'min_humidity': 65.7,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.1},
#    'geometry': {'type': 'Point', 'coordinates': [98.56, 3.501]}},
#   {'id': '34',
#    'type': 'Feature',
#    'properties': {'lokasi': 96037,
#     'Nama UPT': 'Stasiun Geofisika Deli Serdang',
#     'LON': 98.56,
#     'LAT': 3.501,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 31.2,
#     'mean_temp': 27.3,
#     'min_temp': 24.6,
#     'max_humidity': 97.5,
#     'mean_humidity': 85.8,
#     'min_humidity': 68.2,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.1},
#    'geometry': {'type': 'Point', 'coordinates': [98.56, 3.501]}},
#   {'id': '35',
#    'type': 'Feature',
#    'properties': {'lokasi': 96037,
#     'Nama UPT': 'Stasiun Geofisika Deli Serdang',
#     'LON': 98.56,
#     'LAT': 3.501,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 29.9,
#     'mean_temp': 27.6,
#     'min_temp': 25.0,
#     'max_humidity': 96.4,
#     'mean_humidity': 84.1,
#     'min_humidity': 71.9,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [98.56, 3.501]}},
#   {'id': '36',
#    'type': 'Feature',
#    'properties': {'lokasi': 96041,
#     'Nama UPT': 'Balai Besar MKG Wilayah I Medan',
#     'LON': 98.64,
#     'LAT': 3.5397,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 25.8,
#     'mean_temp': 25.3,
#     'min_temp': 24.9,
#     'max_humidity': 96.5,
#     'mean_humidity': 94.6,
#     'min_humidity': 92.5,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [98.64, 3.5397]}},
#   {'id': '37',
#    'type': 'Feature',
#    'properties': {'lokasi': 96041,
#     'Nama UPT': 'Balai Besar MKG Wilayah I Medan',
#     'LON': 98.64,
#     'LAT': 3.5397,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 30.7,
#     'mean_temp': 27.3,
#     'min_temp': 25.1,
#     'max_humidity': 94.9,
#     'mean_humidity': 85.4,
#     'min_humidity': 71.3,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [98.64, 3.5397]}},
#   {'id': '38',
#    'type': 'Feature',
#    'properties': {'lokasi': 96041,
#     'Nama UPT': 'Balai Besar MKG Wilayah I Medan',
#     'LON': 98.64,
#     'LAT': 3.5397,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 30.3,
#     'mean_temp': 27.4,
#     'min_temp': 25.1,
#     'max_humidity': 94.3,
#     'mean_humidity': 83.6,
#     'min_humidity': 70.2,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [98.64, 3.5397]}},
#   {'id': '39',
#    'type': 'Feature',
#    'properties': {'lokasi': 96041,
#     'Nama UPT': 'Balai Besar MKG Wilayah I Medan',
#     'LON': 98.64,
#     'LAT': 3.5397,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 29.1,
#     'mean_temp': 27.3,
#     'min_temp': 25.1,
#     'max_humidity': 94.5,
#     'mean_humidity': 85.8,
#     'min_humidity': 77.6,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [98.64, 3.5397]}},
#   {'id': '40',
#    'type': 'Feature',
#    'properties': {'lokasi': 96043,
#     'Nama UPT': 'Stasiun Meteorologi Silangit',
#     'LON': 98.99357,
#     'LAT': 2.26136,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 17.9,
#     'mean_temp': 17.3,
#     'min_temp': 16.8,
#     'max_humidity': 100.3,
#     'mean_humidity': 99.5,
#     'min_humidity': 98.8,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [98.99357, 2.26136]}},
#   {'id': '41',
#    'type': 'Feature',
#    'properties': {'lokasi': 96043,
#     'Nama UPT': 'Stasiun Meteorologi Silangit',
#     'LON': 98.99357,
#     'LAT': 2.26136,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 25.1,
#     'mean_temp': 21.2,
#     'min_temp': 18.4,
#     'max_humidity': 99.7,
#     'mean_humidity': 87.9,
#     'min_humidity': 67.4,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [98.99357, 2.26136]}},
#   {'id': '42',
#    'type': 'Feature',
#    'properties': {'lokasi': 96043,
#     'Nama UPT': 'Stasiun Meteorologi Silangit',
#     'LON': 98.99357,
#     'LAT': 2.26136,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 24.4,
#     'mean_temp': 21.2,
#     'min_temp': 18.9,
#     'max_humidity': 99.7,
#     'mean_humidity': 91.1,
#     'min_humidity': 80.3,
#     'max_precipitation': 0.6,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [98.99357, 2.26136]}},
#   {'id': '43',
#    'type': 'Feature',
#    'properties': {'lokasi': 96043,
#     'Nama UPT': 'Stasiun Meteorologi Silangit',
#     'LON': 98.99357,
#     'LAT': 2.26136,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 22.2,
#     'mean_temp': 21.1,
#     'min_temp': 18.8,
#     'max_humidity': 99.0,
#     'mean_humidity': 89.4,
#     'min_humidity': 81.5,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [98.99357, 2.26136]}},
#   {'id': '44',
#    'type': 'Feature',
#    'properties': {'lokasi': 96071,
#     'Nama UPT': 'Stasiun Meteorologi Aek Godang',
#     'LON': 99.45,
#     'LAT': 1.55,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 24.7,
#     'mean_temp': 24.4,
#     'min_temp': 24.0,
#     'max_humidity': 87.8,
#     'mean_humidity': 82.8,
#     'min_humidity': 79.2,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [99.45, 1.55]}},
#   {'id': '45',
#    'type': 'Feature',
#    'properties': {'lokasi': 96071,
#     'Nama UPT': 'Stasiun Meteorologi Aek Godang',
#     'LON': 99.45,
#     'LAT': 1.55,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 30.1,
#     'mean_temp': 26.5,
#     'min_temp': 23.8,
#     'max_humidity': 92.8,
#     'mean_humidity': 80.9,
#     'min_humidity': 65.1,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [99.45, 1.55]}},
#   {'id': '46',
#    'type': 'Feature',
#    'properties': {'lokasi': 96071,
#     'Nama UPT': 'Stasiun Meteorologi Aek Godang',
#     'LON': 99.45,
#     'LAT': 1.55,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 29.5,
#     'mean_temp': 26.0,
#     'min_temp': 23.2,
#     'max_humidity': 94.9,
#     'mean_humidity': 84.2,
#     'min_humidity': 70.3,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [99.45, 1.55]}},
#   {'id': '47',
#    'type': 'Feature',
#    'properties': {'lokasi': 96071,
#     'Nama UPT': 'Stasiun Meteorologi Aek Godang',
#     'LON': 99.45,
#     'LAT': 1.55,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 28.5,
#     'mean_temp': 26.3,
#     'min_temp': 23.6,
#     'max_humidity': 92.9,
#     'mean_humidity': 80.7,
#     'min_humidity': 71.3,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [99.45, 1.55]}},
#   {'id': '48',
#    'type': 'Feature',
#    'properties': {'lokasi': 96073,
#     'Nama UPT': 'Stasiun Meteorologi FL Tobing',
#     'LON': 98.88,
#     'LAT': 1.55,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 24.4,
#     'mean_temp': 24.2,
#     'min_temp': 23.9,
#     'max_humidity': 98.2,
#     'mean_humidity': 97.6,
#     'min_humidity': 97.2,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.4},
#    'geometry': {'type': 'Point', 'coordinates': [98.88, 1.55]}},
#   {'id': '49',
#    'type': 'Feature',
#    'properties': {'lokasi': 96073,
#     'Nama UPT': 'Stasiun Meteorologi FL Tobing',
#     'LON': 98.88,
#     'LAT': 1.55,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 29.3,
#     'mean_temp': 26.2,
#     'min_temp': 24.3,
#     'max_humidity': 96.9,
#     'mean_humidity': 88.7,
#     'min_humidity': 72.9,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [98.88, 1.55]}},
#   {'id': '50',
#    'type': 'Feature',
#    'properties': {'lokasi': 96073,
#     'Nama UPT': 'Stasiun Meteorologi FL Tobing',
#     'LON': 98.88,
#     'LAT': 1.55,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 29.0,
#     'mean_temp': 26.2,
#     'min_temp': 24.4,
#     'max_humidity': 97.7,
#     'mean_humidity': 90.2,
#     'min_humidity': 75.5,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [98.88, 1.55]}},
#   {'id': '51',
#    'type': 'Feature',
#    'properties': {'lokasi': 96073,
#     'Nama UPT': 'Stasiun Meteorologi FL Tobing',
#     'LON': 98.88,
#     'LAT': 1.55,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 27.2,
#     'mean_temp': 25.8,
#     'min_temp': 24.6,
#     'max_humidity': 97.2,
#     'mean_humidity': 90.6,
#     'min_humidity': 84.3,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [98.88, 1.55]}},
#   {'id': '52',
#    'type': 'Feature',
#    'properties': {'lokasi': 96075,
#     'Nama UPT': 'Stasiun Meteorologi Binaka',
#     'LON': 97.7036,
#     'LAT': 1.1649,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 26.0,
#     'mean_temp': 25.9,
#     'min_temp': 25.8,
#     'max_humidity': 98.8,
#     'mean_humidity': 97.5,
#     'min_humidity': 96.4,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [97.7036, 1.1649]}},
#   {'id': '53',
#    'type': 'Feature',
#    'properties': {'lokasi': 96075,
#     'Nama UPT': 'Stasiun Meteorologi Binaka',
#     'LON': 97.7036,
#     'LAT': 1.1649,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 27.8,
#     'mean_temp': 26.8,
#     'min_temp': 25.5,
#     'max_humidity': 98.6,
#     'mean_humidity': 89.5,
#     'min_humidity': 82.7,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [97.7036, 1.1649]}},
#   {'id': '54',
#    'type': 'Feature',
#    'properties': {'lokasi': 96075,
#     'Nama UPT': 'Stasiun Meteorologi Binaka',
#     'LON': 97.7036,
#     'LAT': 1.1649,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 28.3,
#     'mean_temp': 26.5,
#     'min_temp': 25.5,
#     'max_humidity': 98.0,
#     'mean_humidity': 93.5,
#     'min_humidity': 87.2,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [97.7036, 1.1649]}},
#   {'id': '55',
#    'type': 'Feature',
#    'properties': {'lokasi': 96075,
#     'Nama UPT': 'Stasiun Meteorologi Binaka',
#     'LON': 97.7036,
#     'LAT': 1.1649,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 26.5,
#     'mean_temp': 26.2,
#     'min_temp': 25.3,
#     'max_humidity': 98.8,
#     'mean_humidity': 94.6,
#     'min_humidity': 90.8,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [97.7036, 1.1649]}},
#   {'id': '56',
#    'type': 'Feature',
#    'properties': {'lokasi': 96077,
#     'Nama UPT': 'Stasiun Geofisika Gunung Sitoli',
#     'LON': 97.58,
#     'LAT': 1.3,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 23.9,
#     'mean_temp': 23.6,
#     'min_temp': 23.4,
#     'max_humidity': 99.6,
#     'mean_humidity': 98.9,
#     'min_humidity': 98.6,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.4,
#     'min_precipitation': 0.4},
#    'geometry': {'type': 'Point', 'coordinates': [97.58, 1.3]}},
#   {'id': '57',
#    'type': 'Feature',
#    'properties': {'lokasi': 96077,
#     'Nama UPT': 'Stasiun Geofisika Gunung Sitoli',
#     'LON': 97.58,
#     'LAT': 1.3,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 28.1,
#     'mean_temp': 25.9,
#     'min_temp': 23.7,
#     'max_humidity': 98.8,
#     'mean_humidity': 91.6,
#     'min_humidity': 81.8,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [97.58, 1.3]}},
#   {'id': '58',
#    'type': 'Feature',
#    'properties': {'lokasi': 96077,
#     'Nama UPT': 'Stasiun Geofisika Gunung Sitoli',
#     'LON': 97.58,
#     'LAT': 1.3,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 28.6,
#     'mean_temp': 25.4,
#     'min_temp': 23.7,
#     'max_humidity': 98.2,
#     'mean_humidity': 93.1,
#     'min_humidity': 83.2,
#     'max_precipitation': 0.6,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [97.58, 1.3]}},
#   {'id': '59',
#    'type': 'Feature',
#    'properties': {'lokasi': 96077,
#     'Nama UPT': 'Stasiun Geofisika Gunung Sitoli',
#     'LON': 97.58,
#     'LAT': 1.3,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 27.0,
#     'mean_temp': 25.2,
#     'min_temp': 23.7,
#     'max_humidity': 97.3,
#     'mean_humidity': 91.8,
#     'min_humidity': 86.1,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.5,
#     'min_precipitation': 0.4},
#    'geometry': {'type': 'Point', 'coordinates': [97.58, 1.3]}},
#   {'id': '60',
#    'type': 'Feature',
#    'properties': {'lokasi': 96087,
#     'Nama UPT': 'Stasiun Meteorologi Hang Nadim',
#     'LON': 104.11667,
#     'LAT': 1.11667,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 27.9,
#     'mean_temp': 27.2,
#     'min_temp': 26.4,
#     'max_humidity': 92.9,
#     'mean_humidity': 92.0,
#     'min_humidity': 90.4,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [104.11667, 1.11667]}},
#   {'id': '61',
#    'type': 'Feature',
#    'properties': {'lokasi': 96087,
#     'Nama UPT': 'Stasiun Meteorologi Hang Nadim',
#     'LON': 104.11667,
#     'LAT': 1.11667,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 29.0,
#     'mean_temp': 27.1,
#     'min_temp': 25.3,
#     'max_humidity': 93.4,
#     'mean_humidity': 85.8,
#     'min_humidity': 75.1,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [104.11667, 1.11667]}},
#   {'id': '62',
#    'type': 'Feature',
#    'properties': {'lokasi': 96087,
#     'Nama UPT': 'Stasiun Meteorologi Hang Nadim',
#     'LON': 104.11667,
#     'LAT': 1.11667,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 30.3,
#     'mean_temp': 27.8,
#     'min_temp': 26.3,
#     'max_humidity': 90.7,
#     'mean_humidity': 84.5,
#     'min_humidity': 75.1,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [104.11667, 1.11667]}},
#   {'id': '63',
#    'type': 'Feature',
#    'properties': {'lokasi': 96087,
#     'Nama UPT': 'Stasiun Meteorologi Hang Nadim',
#     'LON': 104.11667,
#     'LAT': 1.11667,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 28.0,
#     'mean_temp': 27.4,
#     'min_temp': 26.5,
#     'max_humidity': 95.0,
#     'mean_humidity': 87.0,
#     'min_humidity': 81.9,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [104.11667, 1.11667]}},
#   {'id': '64',
#    'type': 'Feature',
#    'properties': {'lokasi': 96089,
#     'Nama UPT': 'Stasiun Meteorologi Raja Haji Abdullah',
#     'LON': 103.38,
#     'LAT': 1.03,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 27.8,
#     'mean_temp': 27.2,
#     'min_temp': 26.5,
#     'max_humidity': 92.9,
#     'mean_humidity': 91.0,
#     'min_humidity': 90.1,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [103.38, 1.03]}},
#   {'id': '65',
#    'type': 'Feature',
#    'properties': {'lokasi': 96089,
#     'Nama UPT': 'Stasiun Meteorologi Raja Haji Abdullah',
#     'LON': 103.38,
#     'LAT': 1.03,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 28.3,
#     'mean_temp': 27.2,
#     'min_temp': 25.9,
#     'max_humidity': 94.4,
#     'mean_humidity': 88.6,
#     'min_humidity': 77.4,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [103.38, 1.03]}},
#   {'id': '66',
#    'type': 'Feature',
#    'properties': {'lokasi': 96089,
#     'Nama UPT': 'Stasiun Meteorologi Raja Haji Abdullah',
#     'LON': 103.38,
#     'LAT': 1.03,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 29.3,
#     'mean_temp': 27.9,
#     'min_temp': 26.1,
#     'max_humidity': 92.6,
#     'mean_humidity': 84.1,
#     'min_humidity': 71.9,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [103.38, 1.03]}},
#   {'id': '67',
#    'type': 'Feature',
#    'properties': {'lokasi': 96089,
#     'Nama UPT': 'Stasiun Meteorologi Raja Haji Abdullah',
#     'LON': 103.38,
#     'LAT': 1.03,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 28.2,
#     'mean_temp': 27.8,
#     'min_temp': 27.0,
#     'max_humidity': 93.6,
#     'mean_humidity': 86.6,
#     'min_humidity': 81.3,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [103.38, 1.03]}},
#   {'id': '68',
#    'type': 'Feature',
#    'properties': {'lokasi': 96091,
#     'Nama UPT': 'Stasiun Meteorologi Raja Haji Fisabilillah',
#     'LON': 104.5289,
#     'LAT': 0.9227,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 27.9,
#     'mean_temp': 26.6,
#     'min_temp': 25.1,
#     'max_humidity': 93.7,
#     'mean_humidity': 89.2,
#     'min_humidity': 85.1,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [104.5289, 0.9227]}},
#   {'id': '69',
#    'type': 'Feature',
#    'properties': {'lokasi': 96091,
#     'Nama UPT': 'Stasiun Meteorologi Raja Haji Fisabilillah',
#     'LON': 104.5289,
#     'LAT': 0.9227,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 28.9,
#     'mean_temp': 26.8,
#     'min_temp': 25.2,
#     'max_humidity': 94.6,
#     'mean_humidity': 87.7,
#     'min_humidity': 72.7,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [104.5289, 0.9227]}},
#   {'id': '70',
#    'type': 'Feature',
#    'properties': {'lokasi': 96091,
#     'Nama UPT': 'Stasiun Meteorologi Raja Haji Fisabilillah',
#     'LON': 104.5289,
#     'LAT': 0.9227,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 29.2,
#     'mean_temp': 27.5,
#     'min_temp': 25.8,
#     'max_humidity': 94.6,
#     'mean_humidity': 86.3,
#     'min_humidity': 75.1,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [104.5289, 0.9227]}},
#   {'id': '71',
#    'type': 'Feature',
#    'properties': {'lokasi': 96091,
#     'Nama UPT': 'Stasiun Meteorologi Raja Haji Fisabilillah',
#     'LON': 104.5289,
#     'LAT': 0.9227,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 27.8,
#     'mean_temp': 26.9,
#     'min_temp': 25.9,
#     'max_humidity': 94.4,
#     'mean_humidity': 89.2,
#     'min_humidity': 83.6,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [104.5289, 0.9227]}},
#   {'id': '72',
#    'type': 'Feature',
#    'properties': {'lokasi': 96107,
#     'Nama UPT': 'Stasiun Klimatologi Riau',
#     'LON': 101.217,
#     'LAT': 0.407,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 25.5,
#     'mean_temp': 24.9,
#     'min_temp': 24.4,
#     'max_humidity': 95.8,
#     'mean_humidity': 94.1,
#     'min_humidity': 91.0,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [101.217, 0.407]}},
#   {'id': '73',
#    'type': 'Feature',
#    'properties': {'lokasi': 96107,
#     'Nama UPT': 'Stasiun Klimatologi Riau',
#     'LON': 101.217,
#     'LAT': 0.407,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 31.2,
#     'mean_temp': 27.2,
#     'min_temp': 24.7,
#     'max_humidity': 96.0,
#     'mean_humidity': 85.5,
#     'min_humidity': 70.7,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.1,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [101.217, 0.407]}},
#   {'id': '74',
#    'type': 'Feature',
#    'properties': {'lokasi': 96107,
#     'Nama UPT': 'Stasiun Klimatologi Riau',
#     'LON': 101.217,
#     'LAT': 0.407,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 30.8,
#     'mean_temp': 26.9,
#     'min_temp': 24.8,
#     'max_humidity': 94.8,
#     'mean_humidity': 85.7,
#     'min_humidity': 69.6,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [101.217, 0.407]}},
#   {'id': '75',
#    'type': 'Feature',
#    'properties': {'lokasi': 96107,
#     'Nama UPT': 'Stasiun Klimatologi Riau',
#     'LON': 101.217,
#     'LAT': 0.407,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 30.7,
#     'mean_temp': 27.7,
#     'min_temp': 25.0,
#     'max_humidity': 94.6,
#     'mean_humidity': 82.2,
#     'min_humidity': 68.7,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [101.217, 0.407]}},
#   {'id': '76',
#    'type': 'Feature',
#    'properties': {'lokasi': 96109,
#     'Nama UPT': 'Stasiun Meteorologi Sultan Syarif Kasim II',
#     'LON': 101.44743,
#     'LAT': 0.45924,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 26.0,
#     'mean_temp': 25.2,
#     'min_temp': 24.8,
#     'max_humidity': 93.4,
#     'mean_humidity': 90.1,
#     'min_humidity': 86.3,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [101.44743, 0.45924]}},
#   {'id': '77',
#    'type': 'Feature',
#    'properties': {'lokasi': 96109,
#     'Nama UPT': 'Stasiun Meteorologi Sultan Syarif Kasim II',
#     'LON': 101.44743,
#     'LAT': 0.45924,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 31.5,
#     'mean_temp': 27.2,
#     'min_temp': 24.5,
#     'max_humidity': 96.4,
#     'mean_humidity': 83.9,
#     'min_humidity': 62.2,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.1,
#     'min_precipitation': -0.1},
#    'geometry': {'type': 'Point', 'coordinates': [101.44743, 0.45924]}},
#   {'id': '78',
#    'type': 'Feature',
#    'properties': {'lokasi': 96109,
#     'Nama UPT': 'Stasiun Meteorologi Sultan Syarif Kasim II',
#     'LON': 101.44743,
#     'LAT': 0.45924,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 30.3,
#     'mean_temp': 27.1,
#     'min_temp': 24.8,
#     'max_humidity': 95.9,
#     'mean_humidity': 85.1,
#     'min_humidity': 72.5,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [101.44743, 0.45924]}},
#   {'id': '79',
#    'type': 'Feature',
#    'properties': {'lokasi': 96109,
#     'Nama UPT': 'Stasiun Meteorologi Sultan Syarif Kasim II',
#     'LON': 101.44743,
#     'LAT': 0.45924,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 30.1,
#     'mean_temp': 27.6,
#     'min_temp': 24.9,
#     'max_humidity': 94.5,
#     'mean_humidity': 82.8,
#     'min_humidity': 71.5,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [101.44743, 0.45924]}},
#   {'id': '80',
#    'type': 'Feature',
#    'properties': {'lokasi': 96145,
#     'Nama UPT': 'Stasiun Meteorologi Tarempa',
#     'LON': 106.25,
#     'LAT': 3.2,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 28.7,
#     'mean_temp': 28.4,
#     'min_temp': 27.8,
#     'max_humidity': 89.0,
#     'mean_humidity': 86.2,
#     'min_humidity': 84.6,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [106.25, 3.2]}},
#   {'id': '81',
#    'type': 'Feature',
#    'properties': {'lokasi': 96145,
#     'Nama UPT': 'Stasiun Meteorologi Tarempa',
#     'LON': 106.25,
#     'LAT': 3.2,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 29.4,
#     'mean_temp': 28.6,
#     'min_temp': 27.8,
#     'max_humidity': 88.7,
#     'mean_humidity': 85.2,
#     'min_humidity': 78.1,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [106.25, 3.2]}},
#   {'id': '82',
#    'type': 'Feature',
#    'properties': {'lokasi': 96145,
#     'Nama UPT': 'Stasiun Meteorologi Tarempa',
#     'LON': 106.25,
#     'LAT': 3.2,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 29.3,
#     'mean_temp': 28.7,
#     'min_temp': 28.3,
#     'max_humidity': 86.0,
#     'mean_humidity': 82.3,
#     'min_humidity': 77.6,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [106.25, 3.2]}},
#   {'id': '83',
#    'type': 'Feature',
#    'properties': {'lokasi': 96145,
#     'Nama UPT': 'Stasiun Meteorologi Tarempa',
#     'LON': 106.25,
#     'LAT': 3.2,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 29.1,
#     'mean_temp': 28.3,
#     'min_temp': 27.6,
#     'max_humidity': 86.0,
#     'mean_humidity': 81.2,
#     'min_humidity': 75.7,
#     'max_precipitation': 0.1,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [106.25, 3.2]}},
#   {'id': '84',
#    'type': 'Feature',
#    'properties': {'lokasi': 96147,
#     'Nama UPT': 'Stasiun Meteorologi Ranai',
#     'LON': 108.39,
#     'LAT': 3.91206,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 29.0,
#     'mean_temp': 27.9,
#     'min_temp': 27.4,
#     'max_humidity': 89.5,
#     'mean_humidity': 88.4,
#     'min_humidity': 86.8,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [108.39, 3.91206]}},
#   {'id': '85',
#    'type': 'Feature',
#    'properties': {'lokasi': 96147,
#     'Nama UPT': 'Stasiun Meteorologi Ranai',
#     'LON': 108.39,
#     'LAT': 3.91206,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 29.7,
#     'mean_temp': 28.7,
#     'min_temp': 27.9,
#     'max_humidity': 88.4,
#     'mean_humidity': 83.7,
#     'min_humidity': 80.3,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [108.39, 3.91206]}},
#   {'id': '86',
#    'type': 'Feature',
#    'properties': {'lokasi': 96147,
#     'Nama UPT': 'Stasiun Meteorologi Ranai',
#     'LON': 108.39,
#     'LAT': 3.91206,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 29.9,
#     'mean_temp': 28.9,
#     'min_temp': 28.2,
#     'max_humidity': 89.0,
#     'mean_humidity': 84.2,
#     'min_humidity': 78.7,
#     'max_precipitation': 0.1,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [108.39, 3.91206]}},
#   {'id': '87',
#    'type': 'Feature',
#    'properties': {'lokasi': 96147,
#     'Nama UPT': 'Stasiun Meteorologi Ranai',
#     'LON': 108.39,
#     'LAT': 3.91206,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 29.0,
#     'mean_temp': 28.7,
#     'min_temp': 28.4,
#     'max_humidity': 87.6,
#     'mean_humidity': 83.8,
#     'min_humidity': 79.3,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [108.39, 3.91206]}},
#   {'id': '88',
#    'type': 'Feature',
#    'properties': {'lokasi': 96161,
#     'Nama UPT': 'Stasiun Meteorologi Maritim Teluk Bayur',
#     'LON': 100.37222,
#     'LAT': -0.99639,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 25.1,
#     'mean_temp': 24.7,
#     'min_temp': 24.4,
#     'max_humidity': 96.1,
#     'mean_humidity': 95.3,
#     'min_humidity': 94.1,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [100.37222, -0.99639]}},
#   {'id': '89',
#    'type': 'Feature',
#    'properties': {'lokasi': 96161,
#     'Nama UPT': 'Stasiun Meteorologi Maritim Teluk Bayur',
#     'LON': 100.37222,
#     'LAT': -0.99639,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 27.8,
#     'mean_temp': 26.2,
#     'min_temp': 24.9,
#     'max_humidity': 94.5,
#     'mean_humidity': 88.1,
#     'min_humidity': 78.9,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [100.37222, -0.99639]}},
#   {'id': '90',
#    'type': 'Feature',
#    'properties': {'lokasi': 96161,
#     'Nama UPT': 'Stasiun Meteorologi Maritim Teluk Bayur',
#     'LON': 100.37222,
#     'LAT': -0.99639,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 27.8,
#     'mean_temp': 26.1,
#     'min_temp': 25.2,
#     'max_humidity': 95.1,
#     'mean_humidity': 89.9,
#     'min_humidity': 80.8,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [100.37222, -0.99639]}},
#   {'id': '91',
#    'type': 'Feature',
#    'properties': {'lokasi': 96161,
#     'Nama UPT': 'Stasiun Meteorologi Maritim Teluk Bayur',
#     'LON': 100.37222,
#     'LAT': -0.99639,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 27.5,
#     'mean_temp': 26.4,
#     'min_temp': 25.3,
#     'max_humidity': 93.2,
#     'mean_humidity': 86.2,
#     'min_humidity': 76.6,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [100.37222, -0.99639]}},
#   {'id': '92',
#    'type': 'Feature',
#    'properties': {'lokasi': 96163,
#     'Nama UPT': 'Stasiun Meteorologi Minangkabau',
#     'LON': 100.28917,
#     'LAT': -0.79355,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 25.3,
#     'mean_temp': 25.0,
#     'min_temp': 24.8,
#     'max_humidity': 95.4,
#     'mean_humidity': 92.6,
#     'min_humidity': 90.5,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [100.28917, -0.79355]}},
#   {'id': '93',
#    'type': 'Feature',
#    'properties': {'lokasi': 96163,
#     'Nama UPT': 'Stasiun Meteorologi Minangkabau',
#     'LON': 100.28917,
#     'LAT': -0.79355,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 28.2,
#     'mean_temp': 26.4,
#     'min_temp': 24.8,
#     'max_humidity': 95.4,
#     'mean_humidity': 88.6,
#     'min_humidity': 79.5,
#     'max_precipitation': 0.4,
# ...
#   {'id': '645',
#    'type': 'Feature',
#    'properties': {'lokasi': 97790,
#     'Nama UPT': 'Stasiun Meteorologi Bandaneira',
#     'LON': 129.9043,
#     'LAT': -4.52338,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 27.6,
#     'mean_temp': 27.1,
#     'min_temp': 26.8,
#     'max_humidity': 88.0,
#     'mean_humidity': 85.8,
#     'min_humidity': 83.9,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [129.9043, -4.52338]}},
#   {'id': '646',
#    'type': 'Feature',
#    'properties': {'lokasi': 97790,
#     'Nama UPT': 'Stasiun Meteorologi Bandaneira',
#     'LON': 129.9043,
#     'LAT': -4.52338,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 27.6,
#     'mean_temp': 27.2,
#     'min_temp': 26.7,
#     'max_humidity': 88.9,
#     'mean_humidity': 83.0,
#     'min_humidity': 74.8,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [129.9043, -4.52338]}},
#   {'id': '647',
#    'type': 'Feature',
#    'properties': {'lokasi': 97790,
#     'Nama UPT': 'Stasiun Meteorologi Bandaneira',
#     'LON': 129.9043,
#     'LAT': -4.52338,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 27.8,
#     'mean_temp': 27.2,
#     'min_temp': 26.6,
#     'max_humidity': 88.5,
#     'mean_humidity': 85.6,
#     'min_humidity': 82.6,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [129.9043, -4.52338]}},
#   {'id': '648',
#    'type': 'Feature',
#    'properties': {'lokasi': 97796,
#     'Nama UPT': 'Stasiun Meteorologi Mozez Kilangin',
#     'LON': 136.89348,
#     'LAT': -4.53006,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 24.8,
#     'mean_temp': 24.5,
#     'min_temp': 24.2,
#     'max_humidity': 97.9,
#     'mean_humidity': 95.8,
#     'min_humidity': 94.1,
#     'max_precipitation': 0.6,
#     'mean_precipitation': 0.5,
#     'min_precipitation': 0.5},
#    'geometry': {'type': 'Point', 'coordinates': [136.89348, -4.53006]}},
#   {'id': '649',
#    'type': 'Feature',
#    'properties': {'lokasi': 97796,
#     'Nama UPT': 'Stasiun Meteorologi Mozez Kilangin',
#     'LON': 136.89348,
#     'LAT': -4.53006,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 30.3,
#     'mean_temp': 26.4,
#     'min_temp': 24.7,
#     'max_humidity': 96.1,
#     'mean_humidity': 90.1,
#     'min_humidity': 76.8,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [136.89348, -4.53006]}},
#   {'id': '650',
#    'type': 'Feature',
#    'properties': {'lokasi': 97796,
#     'Nama UPT': 'Stasiun Meteorologi Mozez Kilangin',
#     'LON': 136.89348,
#     'LAT': -4.53006,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 31.0,
#     'mean_temp': 26.8,
#     'min_temp': 24.5,
#     'max_humidity': 95.8,
#     'mean_humidity': 86.7,
#     'min_humidity': 68.6,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [136.89348, -4.53006]}},
#   {'id': '651',
#    'type': 'Feature',
#    'properties': {'lokasi': 97796,
#     'Nama UPT': 'Stasiun Meteorologi Mozez Kilangin',
#     'LON': 136.89348,
#     'LAT': -4.53006,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 31.2,
#     'mean_temp': 27.5,
#     'min_temp': 25.5,
#     'max_humidity': 94.8,
#     'mean_humidity': 84.8,
#     'min_humidity': 69.0,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [136.89348, -4.53006]}},
#   {'id': '652',
#    'type': 'Feature',
#    'properties': {'lokasi': 97810,
#     'Nama UPT': 'Stasiun Meteorologi Karel Sadsuitubun',
#     'LON': 132.7362,
#     'LAT': -5.6637,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 25.5,
#     'mean_temp': 25.4,
#     'min_temp': 25.3,
#     'max_humidity': 93.8,
#     'mean_humidity': 92.4,
#     'min_humidity': 91.4,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [132.7362, -5.6637]}},
#   {'id': '653',
#    'type': 'Feature',
#    'properties': {'lokasi': 97810,
#     'Nama UPT': 'Stasiun Meteorologi Karel Sadsuitubun',
#     'LON': 132.7362,
#     'LAT': -5.6637,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 29.8,
#     'mean_temp': 26.6,
#     'min_temp': 24.5,
#     'max_humidity': 95.5,
#     'mean_humidity': 85.0,
#     'min_humidity': 67.6,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [132.7362, -5.6637]}},
#   {'id': '654',
#    'type': 'Feature',
#    'properties': {'lokasi': 97810,
#     'Nama UPT': 'Stasiun Meteorologi Karel Sadsuitubun',
#     'LON': 132.7362,
#     'LAT': -5.6637,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 29.7,
#     'mean_temp': 27.1,
#     'min_temp': 25.6,
#     'max_humidity': 94.9,
#     'mean_humidity': 86.2,
#     'min_humidity': 76.5,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [132.7362, -5.6637]}},
#   {'id': '655',
#    'type': 'Feature',
#    'properties': {'lokasi': 97810,
#     'Nama UPT': 'Stasiun Meteorologi Karel Sadsuitubun',
#     'LON': 132.7362,
#     'LAT': -5.6637,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 29.6,
#     'mean_temp': 28.1,
#     'min_temp': 25.6,
#     'max_humidity': 93.0,
#     'mean_humidity': 85.9,
#     'min_humidity': 80.7,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [132.7362, -5.6637]}},
#   {'id': '656',
#    'type': 'Feature',
#    'properties': {'lokasi': 97876,
#     'Nama UPT': 'Stasiun Meteorologi Tanah Merah',
#     'LON': 140.31,
#     'LAT': -6.1,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 24.6,
#     'mean_temp': 24.3,
#     'min_temp': 24.2,
#     'max_humidity': 93.7,
#     'mean_humidity': 92.7,
#     'min_humidity': 92.0,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.2},
#    'geometry': {'type': 'Point', 'coordinates': [140.31, -6.1]}},
#   {'id': '657',
#    'type': 'Feature',
#    'properties': {'lokasi': 97876,
#     'Nama UPT': 'Stasiun Meteorologi Tanah Merah',
#     'LON': 140.31,
#     'LAT': -6.1,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 30.6,
#     'mean_temp': 26.7,
#     'min_temp': 24.6,
#     'max_humidity': 94.0,
#     'mean_humidity': 87.3,
#     'min_humidity': 74.8,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [140.31, -6.1]}},
#   {'id': '658',
#    'type': 'Feature',
#    'properties': {'lokasi': 97876,
#     'Nama UPT': 'Stasiun Meteorologi Tanah Merah',
#     'LON': 140.31,
#     'LAT': -6.1,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 31.9,
#     'mean_temp': 27.5,
#     'min_temp': 24.4,
#     'max_humidity': 95.3,
#     'mean_humidity': 84.1,
#     'min_humidity': 63.8,
#     'max_precipitation': 0.5,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.1},
#    'geometry': {'type': 'Point', 'coordinates': [140.31, -6.1]}},
#   {'id': '659',
#    'type': 'Feature',
#    'properties': {'lokasi': 97876,
#     'Nama UPT': 'Stasiun Meteorologi Tanah Merah',
#     'LON': 140.31,
#     'LAT': -6.1,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 32.2,
#     'mean_temp': 29.2,
#     'min_temp': 27.0,
#     'max_humidity': 87.8,
#     'mean_humidity': 78.2,
#     'min_humidity': 66.5,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.1,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [140.31, -6.1]}},
#   {'id': '660',
#    'type': 'Feature',
#    'properties': {'lokasi': 97900,
#     'Nama UPT': 'Stasiun Meteorologi Mathilda Batlayeri',
#     'LON': 131.3,
#     'LAT': -7.98,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 27.1,
#     'mean_temp': 26.9,
#     'min_temp': 26.8,
#     'max_humidity': 85.5,
#     'mean_humidity': 81.9,
#     'min_humidity': 80.0,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [131.3, -7.98]}},
#   {'id': '661',
#    'type': 'Feature',
#    'properties': {'lokasi': 97900,
#     'Nama UPT': 'Stasiun Meteorologi Mathilda Batlayeri',
#     'LON': 131.3,
#     'LAT': -7.98,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 27.3,
#     'mean_temp': 26.9,
#     'min_temp': 26.3,
#     'max_humidity': 86.9,
#     'mean_humidity': 82.3,
#     'min_humidity': 77.5,
#     'max_precipitation': 0.1,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [131.3, -7.98]}},
#   {'id': '662',
#    'type': 'Feature',
#    'properties': {'lokasi': 97900,
#     'Nama UPT': 'Stasiun Meteorologi Mathilda Batlayeri',
#     'LON': 131.3,
#     'LAT': -7.98,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 27.6,
#     'mean_temp': 27.0,
#     'min_temp': 26.5,
#     'max_humidity': 88.2,
#     'mean_humidity': 81.3,
#     'min_humidity': 77.0,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [131.3, -7.98]}},
#   {'id': '663',
#    'type': 'Feature',
#    'properties': {'lokasi': 97900,
#     'Nama UPT': 'Stasiun Meteorologi Mathilda Batlayeri',
#     'LON': 131.3,
#     'LAT': -7.98,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 27.4,
#     'mean_temp': 27.1,
#     'min_temp': 26.8,
#     'max_humidity': 86.5,
#     'mean_humidity': 84.6,
#     'min_humidity': 82.4,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.1,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [131.3, -7.98]}},
#   {'id': '664',
#    'type': 'Feature',
#    'properties': {'lokasi': 97978,
#     'Nama UPT': 'Stasiun Klimatologi Merauke',
#     'LON': 140.517,
#     'LAT': -8.387,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 24.6,
#     'mean_temp': 24.5,
#     'min_temp': 24.3,
#     'max_humidity': 98.0,
#     'mean_humidity': 95.9,
#     'min_humidity': 92.8,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [140.517, -8.387]}},
#   {'id': '665',
#    'type': 'Feature',
#    'properties': {'lokasi': 97978,
#     'Nama UPT': 'Stasiun Klimatologi Merauke',
#     'LON': 140.517,
#     'LAT': -8.387,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 32.5,
#     'mean_temp': 27.8,
#     'min_temp': 25.1,
#     'max_humidity': 91.1,
#     'mean_humidity': 81.4,
#     'min_humidity': 58.9,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.1,
#     'min_precipitation': -0.2},
#    'geometry': {'type': 'Point', 'coordinates': [140.517, -8.387]}},
#   {'id': '666',
#    'type': 'Feature',
#    'properties': {'lokasi': 97978,
#     'Nama UPT': 'Stasiun Klimatologi Merauke',
#     'LON': 140.517,
#     'LAT': -8.387,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 32.5,
#     'mean_temp': 28.1,
#     'min_temp': 25.1,
#     'max_humidity': 95.8,
#     'mean_humidity': 82.8,
#     'min_humidity': 62.8,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': -0.1},
#    'geometry': {'type': 'Point', 'coordinates': [140.517, -8.387]}},
#   {'id': '667',
#    'type': 'Feature',
#    'properties': {'lokasi': 97978,
#     'Nama UPT': 'Stasiun Klimatologi Merauke',
#     'LON': 140.517,
#     'LAT': -8.387,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 32.5,
#     'mean_temp': 30.0,
#     'min_temp': 26.1,
#     'max_humidity': 89.7,
#     'mean_humidity': 75.8,
#     'min_humidity': 65.9,
#     'max_precipitation': 0.1,
#     'mean_precipitation': -0.0,
#     'min_precipitation': -0.2},
#    'geometry': {'type': 'Point', 'coordinates': [140.517, -8.387]}},
#   {'id': '668',
#    'type': 'Feature',
#    'properties': {'lokasi': 97980,
#     'Nama UPT': 'Stasiun Meteorologi Mopah',
#     'LON': 140.41568,
#     'LAT': -8.52019,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 24.8,
#     'mean_temp': 24.6,
#     'min_temp': 24.3,
#     'max_humidity': 96.0,
#     'mean_humidity': 93.2,
#     'min_humidity': 91.8,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.3,
#     'min_precipitation': 0.3},
#    'geometry': {'type': 'Point', 'coordinates': [140.41568, -8.52019]}},
#   {'id': '669',
#    'type': 'Feature',
#    'properties': {'lokasi': 97980,
#     'Nama UPT': 'Stasiun Meteorologi Mopah',
#     'LON': 140.41568,
#     'LAT': -8.52019,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 30.8,
#     'mean_temp': 27.4,
#     'min_temp': 24.9,
#     'max_humidity': 90.6,
#     'mean_humidity': 81.5,
#     'min_humidity': 69.6,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.0},
#    'geometry': {'type': 'Point', 'coordinates': [140.41568, -8.52019]}},
#   {'id': '670',
#    'type': 'Feature',
#    'properties': {'lokasi': 97980,
#     'Nama UPT': 'Stasiun Meteorologi Mopah',
#     'LON': 140.41568,
#     'LAT': -8.52019,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 31.4,
#     'mean_temp': 27.7,
#     'min_temp': 25.2,
#     'max_humidity': 91.8,
#     'mean_humidity': 81.8,
#     'min_humidity': 65.3,
#     'max_precipitation': 0.4,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [140.41568, -8.52019]}},
#   {'id': '671',
#    'type': 'Feature',
#    'properties': {'lokasi': 97980,
#     'Nama UPT': 'Stasiun Meteorologi Mopah',
#     'LON': 140.41568,
#     'LAT': -8.52019,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 31.6,
#     'mean_temp': 29.7,
#     'min_temp': 26.3,
#     'max_humidity': 88.5,
#     'mean_humidity': 77.2,
#     'min_humidity': 68.9,
#     'max_precipitation': 0.1,
#     'mean_precipitation': 0.1,
#     'min_precipitation': -0.0},
#    'geometry': {'type': 'Point', 'coordinates': [140.41568, -8.52019]}},
#   {'id': '672',
#    'type': 'Feature',
#    'properties': {'lokasi': 99992,
#     'Nama UPT': 'Balai Besar MKG Wilayah II',
#     'LON': 106.75636,
#     'LAT': -6.30253,
#     'day': 17,
#     'Date': '2023-10-17',
#     'max_temp': 28.6,
#     'mean_temp': 26.3,
#     'min_temp': 25.0,
#     'max_humidity': 82.2,
#     'mean_humidity': 77.8,
#     'min_humidity': 70.1,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.2,
#     'min_precipitation': 0.1},
#    'geometry': {'type': 'Point', 'coordinates': [106.75636, -6.30253]}},
#   {'id': '673',
#    'type': 'Feature',
#    'properties': {'lokasi': 99992,
#     'Nama UPT': 'Balai Besar MKG Wilayah II',
#     'LON': 106.75636,
#     'LAT': -6.30253,
#     'day': 18,
#     'Date': '2023-10-18',
#     'max_temp': 33.5,
#     'mean_temp': 29.2,
#     'min_temp': 25.0,
#     'max_humidity': 87.3,
#     'mean_humidity': 69.9,
#     'min_humidity': 50.5,
#     'max_precipitation': 0.3,
#     'mean_precipitation': 0.1,
#     'min_precipitation': -0.1},
#    'geometry': {'type': 'Point', 'coordinates': [106.75636, -6.30253]}},
#   {'id': '674',
#    'type': 'Feature',
#    'properties': {'lokasi': 99992,
#     'Nama UPT': 'Balai Besar MKG Wilayah II',
#     'LON': 106.75636,
#     'LAT': -6.30253,
#     'day': 19,
#     'Date': '2023-10-19',
#     'max_temp': 33.5,
#     'mean_temp': 28.8,
#     'min_temp': 24.4,
#     'max_humidity': 84.8,
#     'mean_humidity': 66.9,
#     'min_humidity': 39.6,
#     'max_precipitation': 0.2,
#     'mean_precipitation': 0.1,
#     'min_precipitation': -0.3},
#    'geometry': {'type': 'Point', 'coordinates': [106.75636, -6.30253]}},
#   {'id': '675',
#    'type': 'Feature',
#    'properties': {'lokasi': 99992,
#     'Nama UPT': 'Balai Besar MKG Wilayah II',
#     'LON': 106.75636,
#     'LAT': -6.30253,
#     'day': 20,
#     'Date': '2023-10-20',
#     'max_temp': 33.5,
#     'mean_temp': 30.8,
#     'min_temp': 26.1,
#     'max_humidity': 80.3,
#     'mean_humidity': 61.1,
#     'min_humidity': 48.9,
#     'max_precipitation': 0.2,
#     'mean_precipitation': -0.1,
#     'min_precipitation': -0.2},
#    'geometry': {'type': 'Point', 'coordinates': [106.75636, -6.30253]}}]}

# %%
geobuf = dlx.geojson_to_geobuf(geojson)
geobuf
# Out:
# '...'
